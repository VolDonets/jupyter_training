# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder, RobustScaler, MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
# %matplotlib inline

# %%
data = pd.read_csv("data/scope_0_1.csv")

# %%
data.head()
# Out:
#      second      Volt
# 0 -0.001050 -0.472379
# 1 -0.001049 -0.472379
# 2 -0.001048 -0.472379
# 3 -0.001047 -0.472379
# 4 -0.001046 -0.472379

# %%
data['second']
# Out:
# 0      -0.001050
# 1      -0.001049
# 2      -0.001048
# 3      -0.001047
# 4      -0.001046
#           ...
# 1995    0.001045
# 1996    0.001046
# 1997    0.001047
# 1998    0.001048
# 1999    0.001049
# Name: second, Length: 2000, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.title("Volate")

plt.plot(data["second"], data["Volt"])

# %%
data = pd.read_csv("data/scope_2_1.csv")
plt.figure(figsize=(12, 6))
plt.title("Volate")

plt.plot(data["second"], data["Volt"])
